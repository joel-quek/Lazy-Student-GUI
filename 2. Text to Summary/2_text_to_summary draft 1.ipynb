# %% [markdown]
# # 2. Text to Summary

# %% [markdown]
# Source: https://www.youtube.com/watch?v=pTHBZ6AyzOg
#
# Title: Summarize Written Text using Google's BERT | Machine Learning | Deep Learning

# %%
import sys

# %%
# !{sys.executable} -m pip install bert-extractive-summarizer

# %%
# !{sys.executable} -m pip install spacy==2.1.3
# Out:
# ...
#   Using cached spacy-2.1.3.tar.gz (27.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [110 lines of output]
# ...
#         Using cached setuptools-65.6.3-py3-none-any.whl (1.2 MB)
# ...
#         Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# ...
#         Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# ...
#         Using cached cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# ...
#         Using cached preshed-2.0.1.tar.gz (113 kB)
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
# ...
#         Using cached murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# ...
#         Using cached thinc-7.0.0.dev6.tar.gz (1.9 MB)
#         Preparing metadata (setup.py): started
# ...

# %%
# !{sys.executable} -m pip install transformers==4.7.0
# Out:
# ...
#      ---------------------------------------- 2.5/2.5 MB 10.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 212.7/212.7 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [51 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-310
#       creating build\lib.win-amd64-cpython-310\tokenizers
# ...

# %%
# !{sys.executable} -m pip install huggingface transformers

# %%
# !{sys.executable} -m pip install neuralcoref
# Out:
# ...
#   Using cached neuralcoref-4.0.tar.gz (368 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for neuralcoref: started
#   Running setup.py install for neuralcoref: finished with status 'error'
#   DEPRECATION: neuralcoref is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for neuralcoref did not run successfully.
#   │ exit code: 1
#   ╰─> [115 lines of output]
#       WARNING: The wheel package is not available.
#       running install
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-3.10
# ...

# %%
from transformers.modeling_bert import BertModel, BertForMaskedLM

# %%
from pprint import pprint

# %%
from transformers import pipeline 
# use bart in pytorch
summarizer = pipeline("summarization")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\redoc\OneDrive\Desktop\DSI-Roughpaper\0. The_Lazy_Student\2. Text to Summary\2_text_to_summary.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20The_Lazy_Student/2.%20Text%20to%20Summary/2_text_to_summary.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> from transformers import pipeline
#       <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20The_Lazy_Student/2.%20Text%20to%20Summary/2_text_to_summary.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> # use bart in pytorch
#       <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20The_Lazy_Student/2.%20Text%20to%20Summary/2_text_to_summary.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> summarizer = pipeline("summarization")
#
# ...

# %%
with open("transcription.txt",'r') as file:
    data=file.read().replace('\n','')

# %%
data=data.replace("\ufeff","")

# %%
model = Summarizer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\redoc\OneDrive\Desktop\DSI-Roughpaper\0. The_Lazy_Student\2. Text to Summary\2_text_to_summary.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20The_Lazy_Student/2.%20Text%20to%20Summary/2_text_to_summary.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> model = Summarizer()
#
# NameError: name 'Summarizer' is not defined
